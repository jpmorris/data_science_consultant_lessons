# %%
import matplotlib.pyplot as plt
import numpy as np




# Fixing random state for reproducibility
np.random.seed(19680801)

x = np.random.sample(800)
y = np.random.sample(800)
z = np.array([0]*800) 
z[4] = 1

# %%
#1d

plt.hist(x, bins=10, histtype='step', color='k', label='1D')
# Out:
# (array([74., 74., 78., 60., 82., 89., 77., 91., 80., 95.]),
#  array([0.00112704, 0.10094857, 0.20077011, 0.30059164, 0.40041317,
#         0.50023471, 0.60005624, 0.69987778, 0.79969931, 0.89952085,
#         0.99934238]),
#  [<matplotlib.patches.Polygon at 0x77161c937620>])

# %%
#2d
ax = plt.figure().add_subplot()

ax.scatter(x, y)


plt.show()

# %%
#3d
ax = plt.figure().add_subplot(projection='3d')

ax.scatter(x, y, z, zdir='y',  label='points in (x, z)')

# Make legend, set axes limits and labels
ax.legend()
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_zlim(0, 1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Customize the view angle so it's easier to see that the scatter points lie
# on the plane y=0
ax.view_init(elev=20., azim=-35, roll=0)

plt.show()
